# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
student_dropout =  pd.read_csv("../datasets/DropoutTrainLabels.csv")

# %%
student_dropout
# Out:
#        StudentID  Dropout
# 0         285848        0
# 1         302176        0
# 2         301803        0
# 3         302756        0
# 4         301067        0
# ...          ...      ...
# 12256     317229        0
# 12257     325536        0
# 12258     342013        0
# 12259     359065        0
# 12260     359327        0
#
# [12261 rows x 2 columns]

# %%
student_financial_data = pd.read_csv("../datasets/Student Financial Aid Data/2011-2017_Cohorts_Financial_Aid_and_Fafsa_Data.csv")

# %%
student_financial_data.head()
# Out:
#    ID with leading   cohort  cohort term Marital Status  \
# 0           297957  2011-12            1         Single
# 1           302040  2011-12            1         Single
# 2           234532  2011-12            1         Single
# 3           303486  2011-12            1        Married
# 4           304316  2011-12            1         Single
#
#    Adjusted Gross Income  Parent Adjusted Gross Income  \
# 0                    0.0                           0.0
# 1                18096.0                           0.0
# 2                12383.0                           0.0
# 3                59303.0                           0.0
# 4                25133.0                           0.0
#
#   Father's Highest Grade Level Mother's Highest Grade Level  \
# 0                      College                  High School
# 1                  High School                  High School
# 2                  High School                  High School
# ...

# %%
student_financial_data_11_12 = student_financial_data[student_financial_data["cohort"] == "2011-12"]
student_financial_data_12_13 = student_financial_data[student_financial_data["cohort"] == "2012-13"]
student_financial_data_13_14 = student_financial_data[student_financial_data["cohort"] == "2013-14"]
student_financial_data_14_15 = student_financial_data[student_financial_data["cohort"] == "2014-15"]
student_financial_data_15_16 = student_financial_data[student_financial_data["cohort"] == "2015-16"]
student_financial_data_16_17 = student_financial_data[student_financial_data["cohort"] == "2016-17"]

# %%
student_financial_data_15_16
# Out:
#        ID with leading   cohort  cohort term Marital Status  \
# 8890            341292  2015-16            1         Single
# 8891            348791  2015-16            1         Single
# 8892            347807  2015-16            1         Single
# 8893            343175  2015-16            1         Single
# 8894            347137  2015-16            1         Single
# ...                ...      ...          ...            ...
# 11236           355003  2015-16            3            NaN
# 11237           355196  2015-16            3            NaN
# 11238           355197  2015-16            3            NaN
# 11239           355199  2015-16            3            NaN
# 11240           355200  2015-16            3            NaN
#
#        Adjusted Gross Income  Parent Adjusted Gross Income  \
# 8890                     0.0                       21623.0
# 8891                 22143.0                           0.0
# 8892                     0.0                       39975.0
# ...

# %%
student_financial_data_11_12_id = student_financial_data_11_12[student_financial_data_11_12["ID with leading"].isin(student_dropout['StudentID'])]
student_financial_data_12_13_id = student_financial_data_12_13[student_financial_data_12_13["ID with leading"].isin(student_dropout['StudentID'])]
student_financial_data_13_14_id = student_financial_data_13_14[student_financial_data_13_14["ID with leading"].isin(student_dropout['StudentID'])]
student_financial_data_14_15_id = student_financial_data_14_15[student_financial_data_14_15["ID with leading"].isin(student_dropout['StudentID'])]
student_financial_data_15_16_id = student_financial_data_15_16[student_financial_data_15_16["ID with leading"].isin(student_dropout['StudentID'])]
student_financial_data_16_17_id = student_financial_data_16_17[student_financial_data_16_17["ID with leading"].isin(student_dropout['StudentID'])]

# %%
student_financial_data_11_12_id["StudentID"] = student_financial_data_11_12_id["ID with leading"]
student_financial_data_12_13_id["StudentID"] = student_financial_data_12_13_id["ID with leading"]
student_financial_data_13_14_id["StudentID"] = student_financial_data_13_14_id["ID with leading"]
student_financial_data_14_15_id["StudentID"] = student_financial_data_14_15_id["ID with leading"]
student_financial_data_15_16_id["StudentID"] = student_financial_data_15_16_id["ID with leading"]
student_financial_data_16_17_id["StudentID"] = student_financial_data_16_17_id["ID with leading"]
# Out:
#       ID with leading   cohort  cohort term Marital Status  \
# 1              302040  2011-12            1         Single
# 2              234532  2011-12            1         Single
# 3              303486  2011-12            1        Married
# 4              304316  2011-12            1         Single
# 5              302808  2011-12            1         Single
# ...               ...      ...          ...            ...
# 2296           309929  2011-12            3         Single
# 2297           309943  2011-12            3       Divorced
# 2298           309983  2011-12            3        Married
# 2299           310039  2011-12            3         Single
# 2301           310186  2011-12            3        Married
#
#       Adjusted Gross Income  Parent Adjusted Gross Income  \
# 1                   18096.0                           0.0
# 2                   12383.0                           0.0
# 3                   59303.0                           0.0
# ...

# %%
student_financial_data_11_12
# Out:
#       ID with leading   cohort  cohort term Marital Status  \
# 0              297957  2011-12            1         Single
# 1              302040  2011-12            1         Single
# 2              234532  2011-12            1         Single
# 3              303486  2011-12            1        Married
# 4              304316  2011-12            1         Single
# ...               ...      ...          ...            ...
# 2297           309943  2011-12            3       Divorced
# 2298           309983  2011-12            3        Married
# 2299           310039  2011-12            3         Single
# 2300           310068  2011-12            3         Single
# 2301           310186  2011-12            3        Married
#
#       Adjusted Gross Income  Parent Adjusted Gross Income  \
# 0                       0.0                           0.0
# 1                   18096.0                           0.0
# 2                   12383.0                           0.0
# ...
